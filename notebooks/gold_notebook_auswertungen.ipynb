# %% [markdown]
# # Notebook für die Auswertungen in data/gold

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# # load data from data/silver

# %%
rechnungen_sap_2023 = pd.read_csv("/workspace/data/silver/Rechnungen_SAP_2023.csv", sep=";")
rechnungen_sap_2024 = pd.read_csv("/workspace/data/silver/Rechnungen_SAP_2024.csv", sep=";")
rechnungen_sap_2023_2024 = pd.read_csv("/workspace/data/silver/Rechnungen_SAP_2023_2024.csv", sep=";")


data_dict = {
    "Rechnungen_SAP_2023": rechnungen_sap_2023,
    "Rechnungen_SAP_2024": rechnungen_sap_2024,
    "Rechnungen_SAP_2023_2024": rechnungen_sap_2023_2024
}

# %%
display(rechnungen_sap_2023_2024.sort_values(by="Belegdatum", ascending=False).head(10))
# Out:
#       Rechnungsnummer Bestellnummer  Belegdatum  \
# 68233      R-69453663           NaN  2024-12-30
# 68166      R-72224244           NaN  2024-12-30
# 68154      R-29933305           NaN  2024-12-30
# 68155      R-40086490           NaN  2024-12-30
# 68156      R-21747741    B-96039759  2024-12-30
# 68157      R-34951700           NaN  2024-12-30
# 68159      R-39987437           NaN  2024-12-30
# 68160      R-06548507           NaN  2024-12-30
# 68161      R-58316300           NaN  2024-12-30
# 68162      R-89522610           NaN  2024-12-30
#
#                                             Beschreibung Lieferant_Nummer  \
# 68233                           Schraubendreher mit Bits            L0028
# 68166                               Versand Brief normal            L0193
# 68154                             Schlitzschraubenzieher            L0026
# 68155                           Zylinderschraube 2036402            L0028
# 68156  DIN 933 A4-70 M 16x50 ISO 4017 Sechskantschrauben            L0026
# 68157                        Paket versenden - Transport            L0192
# 68159                               Versand Brief normal            L0190
# 68160            Papier A3 120g /m² weiß Inkjet 100Bl/Pg            L0318
# 68161                           Schraubendreher mit Bits            L0026
# 68162                               Zylinderschraube DIN            L0027
#
#       Sachkonto-Nummer                Sachkonto-Name  Buchungskreis-Nummer  \
# 68233        SK_000003  Maschinenteile und Ersatzte.                     5
# 68166        SK_000008               Porto und Brief                     1
# 68154        SK_000003  Maschinenteile und Ersatzte.                     2
# 68155        SK_000003  Maschinenteile und Ersatzte.                     1
# 68156        SK_000003  Maschinenteile und Ersatzte.                     5
# 68157        SK_000008               Porto und Brief                     4
# 68159        SK_000008               Porto und Brief                     5
# 68160        SK_000030                    Bürobedarf                     1
# 68161        SK_000003  Maschinenteile und Ersatzte.                     1
# 68162        SK_000003  Maschinenteile und Ersatzte.                     3
#
#                Buchungskreis-Name Material-Nummer  \
# 68233               US plant Inc.             NaN
# 68166        Produktion Bonn GmbH             NaN
# 68154  Vertriebsgesellschaft GmbH             NaN
# 68155        Produktion Bonn GmbH             NaN
# 68156               US plant Inc.           M-004
# 68157    Auslandsgesellschaft SRO             NaN
# 68159               US plant Inc.             NaN
# 68160        Produktion Bonn GmbH             NaN
# 68161        Produktion Bonn GmbH             NaN
# 68162          Verwaltung Demo AG             NaN
#
#                                            Material-Name  ECLASS-identifier  \
# 68233                                                NaN           21040490
# 68166                                                NaN           14081402
# 68154                                                NaN           21040490
# 68155                                                NaN           23110000
# 68156  DIN 933 A4-70 M 16x50 ISO 4017 Sechskantschrauben           23110115
# 68157                                                NaN           14081401
# 68159                                                NaN           14081402
# 68160                                                NaN           24260604
# 68161                                                NaN           21040490
# 68162                                                NaN           23110000
#
#        Menge Mengeneinheit  Stückpreis    Spend Währung  Zahlungsziel-Tage  \
# 68233      1           NaN         NaN   447.17     GBP                 14
# 68166      1           NaN         NaN  1276.24     GBP                  0
# 68154      1           NaN         NaN   609.32     GBP                 14
# 68155      1           NaN         NaN   742.29     GBP                 14
# 68156    167            st         3.0   501.00     GBP                 14
# 68157      1           NaN         NaN  1160.22     GBP                 14
# 68159      1           NaN         NaN  1812.34     GBP                 60
# 68160      1           NaN         NaN   739.62     GBP                 30
# 68161      1           NaN         NaN   701.25     GBP                 14
# 68162      1           NaN         NaN   529.53     GBP                 30
#
#           Zahlungsbedingung Zahlungsfrist Zahlungsdatum Rahmenvertrag  \
# 68233  14 Tage; 1,5% Skonto    2024-01-13    2024-02-17           NaN
# 68166     Sofort ohne Abzug    2024-12-30    2024-12-25           NaN
# 68154         14 Tage netto    2024-01-13    2024-01-15           NaN
# 68155  14 Tage; 1,5% Skonto    2024-01-13    2024-01-07           NaN
# 68156         14 Tage netto    2024-01-13    2024-01-08           NaN
# 68157  14 Tage; 1,5% Skonto    2024-01-13    2024-01-27           NaN
# 68159         60 Tage netto    2024-02-28    2024-03-30           NaN
# 68160    30 Tage; 1% Skonto    2024-01-29    2024-02-21           NaN
# 68161         14 Tage netto    2024-01-13    2024-01-23           NaN
# 68162         30 Tage netto    2024-01-29    2024-03-04    V-52290328
#
#                    Lieferantenname  Wechselkurs    Spend_EUR
# 68233   Maschinenbau GmbH & Co. KG       1.1682   522.383994
# 68166          Deutsche Post  GmbH       1.2077  1541.315048
# 68154            Robert Bosch GmbH       1.1618   707.907976
# 68155   Maschinenbau GmbH & Co. KG       1.1600   861.056400
# 68156            Robert Bosch GmbH       1.1608   581.560800
# 68157        Deutsche Post Germany       1.1714  1359.081708
# 68159             Deutsche Post AG       1.1695  2119.531630
# 68160             Wasserleasing AG       1.1680   863.876160
# 68161            Robert Bosch GmbH       1.1697   820.252125
# 68162                 ROBERT BOSCH       1.1685   618.755805

# %% [markdown]
# ## Ausgabe der ersten Zeilen

# %%
pd.set_option('display.max_columns', None)  # Show all columns in the output
pd.set_option('display.max_rows', None)  # Show all rows in the output

# %%
for i in data_dict.keys():
    print(f"Data from {i}:")
    print("Anzahl Spalten:", data_dict[i].shape[1], "Anzahl Zeilen:", data_dict[i].shape[0])
    display(data_dict[i].head())
    print("\n")
# Out:
# Data from Rechnungen_SAP_2023:
# Anzahl Spalten: 25 Anzahl Zeilen: 34152
#   Rechnungsnummer Bestellnummer  Belegdatum  \
# 0      R-81402060           NaN  2023-01-01
# 1      R-60983007           NaN  2023-01-01
# 2      R-51330234           NaN  2023-01-01
# 3      R-62280354           NaN  2023-01-01
# 4      R-21995158           NaN  2023-01-01
#
#                                         Beschreibung Lieferant_Nummer  \
# 0                              Versand Kundenprämien            L0194
# 1                               Zylinderschraube DIN            L0027
# 2  Dummy Klaus Ludwig Leopard-Sicherheitsschuhe T...            L0097
# 3                                      SPIBO premium            L0028
# 4                                      SPIBO premium            L0028
#
#   Sachkonto-Nummer                Sachkonto-Name  Buchungskreis-Nummer  \
# 0        SK_000008               Porto und Brief                     2
# 1        SK_000003  Maschinenteile und Ersatzte.                     1
# 2        SK_000004      Arbeitssicherheit, Ausr.                     2
# 3        SK_000003  Maschinenteile und Ersatzte.                     4
# 4        SK_000003  Maschinenteile und Ersatzte.                     4
#
#            Buchungskreis-Name Material-Nummer Material-Name  \
# 0  Vertriebsgesellschaft GmbH             NaN           NaN
# 1        Produktion Bonn GmbH             NaN           NaN
# 2  Vertriebsgesellschaft GmbH             NaN           NaN
# 3    Auslandsgesellschaft SRO             NaN           NaN
# 4    Auslandsgesellschaft SRO             NaN           NaN
#
#    ECLASS-identifier  Menge Mengeneinheit  Stückpreis     Spend Währung  \
# 0           14020000      1           NaN         NaN    683.40     EUR
# 1           23110000      1           NaN         NaN    211.53     EUR
# 2           40250703      1           NaN         NaN   8655.51     EUR
# 3           21182301      1           NaN         NaN  10937.30     EUR
# 4           21182301      1           NaN         NaN  10991.05     EUR
#
#    Zahlungsziel-Tage     Zahlungsbedingung Zahlungsfrist Zahlungsdatum  \
# 0                 14         14 Tage netto    2023-01-15    2023-01-09
# 1                 30         30 Tage netto    2023-01-31    2023-02-10
# 2                 30    30 Tage; 1% Skonto    2023-01-31    2023-01-25
# 3                 14  14 Tage; 1,5% Skonto    2023-01-15    2023-01-11
# 4                 14  14 Tage; 1,5% Skonto    2023-01-15    2023-01-29
#
#   Rahmenvertrag              Lieferantenname  Wechselkurs  Spend_EUR
# 0           NaN   Deutsche Post GmbH & Co.KG          1.0     683.40
# 1    V-74154614                 ROBERT BOSCH          1.0     211.53
# 2           NaN        Engelbert und Strauss          1.0    8655.51
# 3           NaN   Maschinenbau GmbH & Co. KG          1.0   10937.30
# 4           NaN   Maschinenbau GmbH & Co. KG          1.0   10991.05
# Data from Rechnungen_SAP_2024:
# Anzahl Spalten: 25 Anzahl Zeilen: 34082
#   Rechnungsnummer Bestellnummer  Belegdatum  \
# 0      R-19934029           NaN  2024-01-01
# 1      R-20408868           NaN  2024-01-01
# 2      R-53946015           NaN  2024-01-01
# 3      R-49696293           NaN  2024-01-01
# 4      R-45623784           NaN  2024-01-01
#
#                                         Beschreibung Lieferant_Nummer  \
# 0                                     Papier weiß A3            L0318
# 1                                   Zylinderschraube            L0028
# 2                               Zylinderschraube DIN            L0028
# 3  Test Runddrahtbürsten Ø x-mm Edelstdr. gew.,mm...            L0028
# 4                            Gas Pauschale September            L0315
#
#   Sachkonto-Nummer                         Sachkonto-Name  \
# 0        SK_000002  Verrechnung vorherige Buchungsperiode
# 1        SK_000003           Maschinenteile und Ersatzte.
# 2        SK_000003           Maschinenteile und Ersatzte.
# 3        SK_000003           Maschinenteile und Ersatzte.
# 4        SK_000020                                Energie
#
#    Buchungskreis-Nummer        Buchungskreis-Name Material-Nummer  \
# 0                     3        Verwaltung Demo AG             NaN
# 1                     3        Verwaltung Demo AG             NaN
# 2                     4  Auslandsgesellschaft SRO             NaN
# 3                     3        Verwaltung Demo AG             NaN
# 4                     4  Auslandsgesellschaft SRO             NaN
#
#   Material-Name  ECLASS-identifier  Menge Mengeneinheit  Stückpreis     Spend  \
# 0           NaN           24260604      1           NaN         NaN   1217.95
# 1           NaN           23110000      1           NaN         NaN    592.38
# 2           NaN           23110000      1           NaN         NaN    419.30
# 3           NaN           21190605      1           NaN         NaN   2804.05
# 4           NaN           26040201      1           NaN         NaN  34259.35
#
#   Währung  Zahlungsziel-Tage     Zahlungsbedingung Zahlungsfrist  \
# 0     USD                 30    30 Tage; 1% Skonto    2024-01-31
# 1     USD                 14  14 Tage; 1,5% Skonto    2024-01-15
# 2     USD                 14  14 Tage; 1,5% Skonto    2024-01-15
# 3     USD                 14  14 Tage; 1,5% Skonto    2024-01-15
# 4     USD                 30         30 Tage netto    2024-01-31
#
#   Zahlungsdatum Rahmenvertrag              Lieferantenname  Wechselkurs  \
# 0    2024-01-28           NaN             Wasserleasing AG      0.91988
# 1    2024-02-11           NaN   Maschinenbau GmbH & Co. KG      0.92833
# 2    2024-01-09           NaN   Maschinenbau GmbH & Co. KG      0.91408
# 3    2024-01-09           NaN   Maschinenbau GmbH & Co. KG      0.91408
# 4    2024-01-26    V-27993028         Stadtwerke Bonn GmbH      0.91988
#
#       Spend_EUR
# 0   1120.367846
# 1    549.924125
# 2    383.273744
# 3   2563.126024
# 4  31514.490878
# Data from Rechnungen_SAP_2023_2024:
# Anzahl Spalten: 25 Anzahl Zeilen: 68234
#   Rechnungsnummer Bestellnummer  Belegdatum  \
# 0      R-81402060           NaN  2023-01-01
# 1      R-60983007           NaN  2023-01-01
# 2      R-51330234           NaN  2023-01-01
# 3      R-62280354           NaN  2023-01-01
# 4      R-21995158           NaN  2023-01-01
#
#                                         Beschreibung Lieferant_Nummer  \
# 0                              Versand Kundenprämien            L0194
# 1                               Zylinderschraube DIN            L0027
# 2  Dummy Klaus Ludwig Leopard-Sicherheitsschuhe T...            L0097
# 3                                      SPIBO premium            L0028
# 4                                      SPIBO premium            L0028
#
#   Sachkonto-Nummer                Sachkonto-Name  Buchungskreis-Nummer  \
# 0        SK_000008               Porto und Brief                     2
# 1        SK_000003  Maschinenteile und Ersatzte.                     1
# 2        SK_000004      Arbeitssicherheit, Ausr.                     2
# 3        SK_000003  Maschinenteile und Ersatzte.                     4
# 4        SK_000003  Maschinenteile und Ersatzte.                     4
#
#            Buchungskreis-Name Material-Nummer Material-Name  \
# 0  Vertriebsgesellschaft GmbH             NaN           NaN
# 1        Produktion Bonn GmbH             NaN           NaN
# 2  Vertriebsgesellschaft GmbH             NaN           NaN
# 3    Auslandsgesellschaft SRO             NaN           NaN
# 4    Auslandsgesellschaft SRO             NaN           NaN
#
#    ECLASS-identifier  Menge Mengeneinheit  Stückpreis     Spend Währung  \
# 0           14020000      1           NaN         NaN    683.40     EUR
# 1           23110000      1           NaN         NaN    211.53     EUR
# 2           40250703      1           NaN         NaN   8655.51     EUR
# 3           21182301      1           NaN         NaN  10937.30     EUR
# 4           21182301      1           NaN         NaN  10991.05     EUR
#
#    Zahlungsziel-Tage     Zahlungsbedingung Zahlungsfrist Zahlungsdatum  \
# 0                 14         14 Tage netto    2023-01-15    2023-01-09
# 1                 30         30 Tage netto    2023-01-31    2023-02-10
# 2                 30    30 Tage; 1% Skonto    2023-01-31    2023-01-25
# 3                 14  14 Tage; 1,5% Skonto    2023-01-15    2023-01-11
# 4                 14  14 Tage; 1,5% Skonto    2023-01-15    2023-01-29
#
#   Rahmenvertrag              Lieferantenname  Wechselkurs  Spend_EUR
# 0           NaN   Deutsche Post GmbH & Co.KG          1.0     683.40
# 1    V-74154614                 ROBERT BOSCH          1.0     211.53
# 2           NaN        Engelbert und Strauss          1.0    8655.51
# 3           NaN   Maschinenbau GmbH & Co. KG          1.0   10937.30
# 4           NaN   Maschinenbau GmbH & Co. KG          1.0   10991.05

# %% [markdown]
# # Auswertung 1

# %%
def top10_lieferanten(df: pd.DataFrame) -> pd.DataFrame:
    """
    Gibt die Top 10 Lieferanten basierend auf der Spendensumme in EUR zurück.

    Args:
        df (pd.DataFrame): Das DataFrame, das die Rechnungsdaten enthält.

    Returns:
        pd.DataFrame: Ein DataFrame mit den Top 10 Lieferanten mit den Spalten Lieferantennummer, Lieferantenname und Spend in EUR (aggregiert).
    """
    top10 = df.groupby("Lieferantenname")["Spend_EUR"].sum().nlargest(10).index

    result = (
        df[df["Lieferantenname"].isin(top10)]
        .groupby(["Lieferant_Nummer", "Lieferantenname"], as_index=False)["Spend_EUR"]
        .sum()
        .sort_values("Spend_EUR", ascending=False)
    )

    result["Spend_EUR"] = result["Spend_EUR"].round(2)

    return result.reset_index(drop=True).rename(columns={"Lieferant_Nummer": "Lieferantennummer",  "Spend_EUR": "Spend in EUR"})

# %%
auswertung_1_2023 = top10_lieferanten(rechnungen_sap_2023)
auswertung_1_2024 = top10_lieferanten(rechnungen_sap_2024)
auswertung_1_2023_2024 = top10_lieferanten(rechnungen_sap_2023_2024)

# %%
display(auswertung_1_2023)
display(auswertung_1_2024)
display(auswertung_1_2023_2024)
# Out:
#   Lieferantennummer                       Lieferantenname  Spend in EUR
# 0             L0008                           Krupp+Essen   26263462.67
# 1             L0236   Vereinigte Papierwarenfabriken GmbH   13649792.79
# 2             L0006                   KRUPP ESSEN GERMANY   13078860.75
# 3             L0003                     TATA STEEL EUROPE   12319851.55
# 4             L0005               Krupp Essen Deutschland   10706453.83
# 5             L0026                     Robert Bosch GmbH    9888120.26
# 6             L0316               Stadtwerke Köln Öl GmbH    8919482.39
# 7             L0028            Maschinenbau GmbH & Co. KG    8112556.69
# 8             L0027                          ROBERT BOSCH    7697666.82
# 9             L0315                  Stadtwerke Bonn GmbH    6157639.70
#   Lieferantennummer                       Lieferantenname  Spend in EUR
# 0             L0008                           Krupp+Essen   20331322.71
# 1             L0236   Vereinigte Papierwarenfabriken GmbH   14199946.67
# 2             L0006                   KRUPP ESSEN GERMANY   11960126.88
# 3             L0003                     TATA STEEL EUROPE   11763138.61
# 4             L0005               Krupp Essen Deutschland    9691172.18
# 5             L0026                     Robert Bosch GmbH    9652842.85
# 6             L0316               Stadtwerke Köln Öl GmbH    8413607.45
# 7             L0028            Maschinenbau GmbH & Co. KG    7989877.14
# 8             L0027                          ROBERT BOSCH    6857317.25
# 9             L0303             Mercateo Deutschland GmbH    6740353.60
#   Lieferantennummer                       Lieferantenname  Spend in EUR
# 0             L0008                           Krupp+Essen   46594785.38
# 1             L0236   Vereinigte Papierwarenfabriken GmbH   27849739.46
# 2             L0006                   KRUPP ESSEN GERMANY   25038987.62
# 3             L0003                     TATA STEEL EUROPE   24082990.16
# 4             L0005               Krupp Essen Deutschland   20397626.02
# 5             L0026                     Robert Bosch GmbH   19540963.10
# 6             L0316               Stadtwerke Köln Öl GmbH   17333089.84
# 7             L0028            Maschinenbau GmbH & Co. KG   16102433.83
# 8             L0027                          ROBERT BOSCH   14554984.06
# 9             L0303             Mercateo Deutschland GmbH   12212917.37

# %% [markdown]
# # Auswertung 2

# %%
def top10_sachkonten(df: pd.DataFrame) -> pd.DataFrame:
    """
    Gibt die Top 10 Sachkonten basierend auf der Anzahl der Rechnungen zurück.

    Args:
        df (pd.DataFrame): Das DataFrame mit den Rechnungsdaten.

    Returns:
        pd.DataFrame: Ein DataFrame mit den Top 10 Sachkonten, bestehend aus:
                      Sachkonto-Nummer, Sachkonto-Name und Anzahl der Rechnungen.
    """
    # Gruppierung nach Sachkonto-Nummer und -Name, Zählen der Einträge
    grouped = (
        df.groupby(["Sachkonto-Nummer", "Sachkonto-Name"])
        .size()
        .reset_index(name="Anzahl")
    )

    # Top 10 mit den meisten Rechnungen
    top10 = grouped.sort_values("Anzahl", ascending=False).head(10).reset_index(drop=True)

    return top10.rename(columns={"Sachkonto-Nummer": "Sachkontonummer", "Sachkonto-Name": "Sachkontoname"})

# %%
auswertung_2_2023 = top10_sachkonten(rechnungen_sap_2023)
auswertung_2_2024 = top10_sachkonten(rechnungen_sap_2024)
auswertung_2_2023_2024 = top10_sachkonten(rechnungen_sap_2023_2024)

# %%
display(auswertung_2_2023)
display(auswertung_2_2024)
display(auswertung_2_2023_2024)
# Out:
#   Sachkontonummer                          Sachkontoname  Anzahl
# 0       SK_000003           Maschinenteile und Ersatzte.   16267
# 1       SK_000009                               Logistik    6791
# 2       SK_000008                        Porto und Brief    2583
# 3       SK_000030                             Bürobedarf    2030
# 4       SK_000001                           Wareneinkauf    1604
# 5       SK_000004               Arbeitssicherheit, Ausr.    1560
# 6       SK_000002  Verrechnung vorherige Buchungsperiode     998
# 7       SK_000022               Reinigungsdienstleistung     595
# 8       SK_000005               Aufwendungen für Gebäude     328
# 9       SK_000007                         Logistikbedarf     304
#   Sachkontonummer                          Sachkontoname  Anzahl
# 0       SK_000003           Maschinenteile und Ersatzte.   16294
# 1       SK_000009                               Logistik    6970
# 2       SK_000008                        Porto und Brief    2485
# 3       SK_000030                             Bürobedarf    2122
# 4       SK_000001                           Wareneinkauf    1515
# 5       SK_000004               Arbeitssicherheit, Ausr.    1442
# 6       SK_000002  Verrechnung vorherige Buchungsperiode     965
# 7       SK_000022               Reinigungsdienstleistung     606
# 8       SK_000005               Aufwendungen für Gebäude     309
# 9       SK_000007                         Logistikbedarf     304
#   Sachkontonummer                          Sachkontoname  Anzahl
# 0       SK_000003           Maschinenteile und Ersatzte.   32561
# 1       SK_000009                               Logistik   13761
# 2       SK_000008                        Porto und Brief    5068
# 3       SK_000030                             Bürobedarf    4152
# 4       SK_000001                           Wareneinkauf    3119
# 5       SK_000004               Arbeitssicherheit, Ausr.    3002
# 6       SK_000002  Verrechnung vorherige Buchungsperiode    1963
# 7       SK_000022               Reinigungsdienstleistung    1201
# 8       SK_000005               Aufwendungen für Gebäude     637
# 9       SK_000007                         Logistikbedarf     608

# %% [markdown]
# # Auswertung 3

# %%
def monatlicher_spendverlauf(df: pd.DataFrame) -> pd.DataFrame:
    """
    Ermittelt den zeitlichen Verlauf des Spends in EUR (2023–2024) pro Monat.

    Args:
        df (pd.DataFrame): DataFrame mit einer Spalte 'Belegdatum' (datetime) und 'Spend_EUR' (float)

    Returns:
        pd.DataFrame: DataFrame mit den Spalten 'Jahr', 'Monat', 'Spend_EUR'
    """
    df = df.copy()

    # Belegdatum sicherstellen
    df["Belegdatum"] = pd.to_datetime(df["Belegdatum"], errors="coerce")

    # Jahr und Monat extrahieren
    df["Jahr"] = df["Belegdatum"].dt.year
    df["Monat"] = df["Belegdatum"].dt.month

    # Gruppieren und aufsummieren
    result = (
        df.groupby(["Jahr", "Monat"], as_index=False)["Spend_EUR"]
        .sum()
        .sort_values(["Jahr", "Monat"])
        .reset_index(drop=True)
    )
    result["Spend_EUR"] = result["Spend_EUR"].round(2)

    return result.rename(columns={"Spend_EUR": "Spend in EUR"})

# %%
auswertung_3_2023_2024 = monatlicher_spendverlauf(rechnungen_sap_2023_2024)

# %%
display(auswertung_3_2023_2024)
# Out:
#     Jahr  Monat  Spend in EUR
# 0   2023      1   21937171.95
# 1   2023      2   19494676.06
# 2   2023      3   21681447.35
# 3   2023      4   20161640.35
# 4   2023      5   21109044.86
# 5   2023      6   22145689.90
# 6   2023      7   24201765.39
# 7   2023      8   25174808.22
# 8   2023      9   27610596.94
# 9   2023     10   25873322.46
# 10  2023     11   25108758.90
# 11  2023     12   26301564.48
# 12  2024      1   19794847.81
# 13  2024      2   20360975.56
# 14  2024      3   20953851.08
# 15  2024      4   19924047.76
# 16  2024      5   19701229.26
# 17  2024      6   22302838.08
# 18  2024      7   21203398.22
# 19  2024      8   22619376.11
# 20  2024      9   20272718.41
# 21  2024     10   19582075.22
# 22  2024     11   26071034.01
# 23  2024     12   26037121.56

# %% [markdown]
# # Speichern der Ergebnisse

# %%
auswertung_1_2023.to_csv("/workspace/data/gold/auswertung_1_2023.csv", index=False, sep=";")
auswertung_1_2024.to_csv("/workspace/data/gold/auswertung_1_2024.csv", index=False, sep=";")
auswertung_1_2023_2024.to_csv("/workspace/data/gold/auswertung_1_2023_2024.csv", index=False, sep=";")

auswertung_2_2023.to_csv("/workspace/data/gold/auswertung_2_2023.csv", index=False, sep=";")
auswertung_2_2024.to_csv("/workspace/data/gold/auswertung_2_2024.csv", index=False, sep=";")
auswertung_2_2023_2024.to_csv("/workspace/data/gold/auswertung_2_2023_2024.csv", index=False, sep=";")

auswertung_3_2023_2024.to_csv("/workspace/data/gold/auswertung_3_2023_2024.csv", index=False, sep=";")
